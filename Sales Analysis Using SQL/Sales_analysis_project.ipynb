# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **Asma Zahoor** is an aspiring data professional at **Data Seekho**.
# - 📚 Learning **Python, SQL, Machine Learning**, and more through **Data Seekho’s** courses.
# - 💻 Engaging in **hands-on projects** and learning from **industry experts**.
# - 🌟 Part of **Data Seekho’s supportive community**, aiming for top 1% in data.
# - 🎯 Preparing for a **successful career** in Data Science with **Data Seekho**.

# %% [markdown]
# # **Sales Analysis project**
# ### By this project I am doing sales analysis through SQL (structured query language) on custom datasets.
# - I have a sample dataset **sales_data**.
# - Create table using **CREATE** DDL language
# - Define Columns and their data types.

# %% [markdown]
# ![Capture.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### Here i have inserted custom values in columns which last to 20 rows
# - Syntax used to insert data is: **Insert into (coulmn1, column2,..) values (?,?,..);**
# - To insert values in columns of tables every time we need to use this syntax for every row

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Total Sales Revenue**
# To find total sales revenue from given data
# - I have used SQL Aggregate Functions ***SUM*** with columns product
# - I have defined calculation of quantity and reveneue with the name of new column using ***AS***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Top 5 Best Selling Products**
# Here I used ** Group by** and **Order by** to find most selling product category
# - **Select** used to filter out required columns
# - **Group by** groups same rows with the sum of their quantity
# - **Order by** ordered result column in descending to find top 5
# - **Limit** it define limits of rows

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Monthly Sales Trend**
# To find monthly sales trend I used same commands but with different columns

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Regional Sales Breakdown**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Most Popular Product Category**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
